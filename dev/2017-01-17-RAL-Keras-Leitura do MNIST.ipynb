# %%
import keras
# Out:
# Using Theano backend.

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 15286272/15296311 [============================>.] - ETA: 0s

# %%
X_train.shape, X_train.dtype, X_train.min(), X_train.max()
# Out:
# ((60000, 28, 28), dtype('uint8'), 0, 255)

# %%
y_train.shape, y_train.dtype, y_train.min(), y_train.max()
# Out:
# ((60000,), dtype('uint8'), 0, 9)

# %%
X_test.shape, X_test.dtype, X_test.min(), X_test.max()
# Out:
# ((10000, 28, 28), dtype('uint8'), 0, 255)

# %%
y_test.shape, y_test.dtype, y_test.min(), y_test.max()
# Out:
# ((10000,), dtype('uint8'), 0, 9)

# %%
import sys,os
sys.path.append(os.path.abspath('../../ia898/src/')) # para importar nbpil
try:
    sys.imagepath.append(os.path.abspath('../data/')) # caminho para imagens
except:
    sys.imagepath = [os.path.abspath('../data/')]
sys.imagepath.append(os.path.abspath('../../../datasets/ia898/'))
import numpy as np

import nbpil

# %%
nb = nbpil.nbshow(ncols=20)
for i in range(100):
    nb.nbshow(X_train[i], '%d'% (y_train[i],))
nb.nbshow()
# Out:
# <head><style>                table, th, td { border: 0px solid black;                text-align: center;border-collapse: collapse;}</style></head>                <body><table border="0"><tr><td>                    <table><tr><td><img src='data:image/png;base64,...'/></td></tr>                    <tr><td align='center'>5</td></tr></table></td><td>                    <table><tr><td><img src='data:image/png;base64,...'/></td></tr>                    <tr><td align='center'>0</td></tr></table></td><td>                    <table><tr><td><img src='...'/></td></tr>                    <tr><td align='center'>4</td></tr></table></td><td>                    <table><tr><td><img src='...'/></td></tr>                    <tr><td align='center'>1</td></tr></table></td><td>                    <table><tr><td><img src='...'/></td></tr>                    <tr><td align='center'>9</td></tr></table></td><td>                    <table><tr><td><img src='data:image/png;base64,...'/></td></tr>                 
# ...
